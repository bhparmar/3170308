# %% [markdown]
# <a href="https://colab.research.google.com/github/bhparmar/3170308/blob/main/Power_Law_(Gamma)_Transformation.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2
import matplotlib.pyplot as plt 
import math
import numpy as np 
from skimage.io import imread
from skimage.color import rgb2lab, lab2rgb
import matplotlib.pylab as plt
from google.colab.patches import cv2_imshow
from google.colab import files

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
def read_file(filename):
  image = cv2.imread(filename)
  cv2_imshow(image)
  return image

# %%
uploaded = files.upload()

filename = next(iter(uploaded))
image = read_file(filename)
# Out:
#      <input type="file" id="files-5d6eb775-ca61-401c-9daa-ff849b44efcb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5d6eb775-ca61-401c-9daa-ff849b44efcb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving IMG-20200103-WA0055.jpg to IMG-20200103-WA0055.jpg
# <PIL.Image.Image image mode=RGB size=1040x585 at 0x7FB6806550D0>

# %%
# Histogram plotting of the image 
color = ('b', 'g', 'r') 
  
for i, col in enumerate(color): 
      
    histr = cv2.calcHist([image],  
                         [i], None, 
                         [256],  
                         [0, 256]) 
      
    plt.plot(histr, color = col) 
      
    # Limit X - axis to 256 
    plt.xlim([0, 256]) 
      
plt.show()

# %%
# Trying 4 gamma values. 
for gamma in [0.1, 0.5, 1.2, 2.2, 3.2]: 

    # Apply gamma correction. 
    gamma_corrected = np.array(255*(image / 255) ** gamma, dtype = 'uint8') 
    plt.imshow(gamma_corrected) 
    plt.show()

# %%
# Histogram plotting of the 
# log transformed image 
color = ('b', 'g', 'r') 
  
for i, col in enumerate(color): 
      
    histr = cv2.calcHist([gamma_corrected],  
                         [i], None, 
                         [256], 
                         [0, 256]) 
      
    plt.plot(histr, color = col) 
    plt.xlim([0, 256]) 
      
plt.show()
